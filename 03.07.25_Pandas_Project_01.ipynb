# %%
import pandas as pd
import numpy as np

df = pd.read_csv("customers-10000.csv")
df

# %% [markdown]
# ### 1. Display the first 5 rows

# %%
df.head(5)
# Out:
#    Index      Customer Id First Name  Last Name                   Company  \
# 0      1  EB54EF1154C3A78    Heather   Callahan              Mosley-David
# 1      2  10dAcafEBbA5FcA   Kristina    Ferrell  Horn, Shepard and Watson
# 2      3  67DAB15Ebe4BE4a     Briana   Andersen               Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty      Ponce          Richardson Group
# 4      5  5820deAdCF23EFe   Kathleen  Mccormick              Carson-Burch
#
#                City                   Country                Phone 1  \
# 0  Lake Jeffborough                    Norway           043-797-5229
# 1        Aaronville                   Andorra           932-062-1802
# 2       East Jordan                     Nepal             8352752061
# 3  East Kristintown  Northern Mariana Islands           302.398.3833
# 4       Andresmouth                     Macao  001-184-153-9683x1497
#
#               Phone 2                             Email Subscription Date  \
# ...

# %% [markdown]
# ### 2. How many rows and columns are there in the dataset?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %% [markdown]
# ### 3.What are the columns names and their datatypes?

# %%
df.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %% [markdown]
# ### 4. Find all the users country name 'Singapore'.

# %%
df.query("Country == 'Singapore'")
# Out:
#       Index      Customer Id First Name  Last Name  \
# 19       20  e99DcfDaDac8a06     Hannah     Ramsey
# 129     130  ba2E28951F277dd   Kimberly    Gregory
# 437     438  C7C79d8D3CF7Eac     Parker      Brady
# 575     576  8EED68A2517917f      Tanya  Gutierrez
# 1324   1325  D7fCB4AeCb40E54     Rickey      Downs
# 2180   2181  f2bd6BEea14F3cC     Summer      White
# 2284   2285  Df3E1f93B7B5be7       Jodi     Waters
# 2345   2346  6b86dEADBadfEb1     Tyrone       Beck
# 2603   2604  7fd07F597e9eE63     Alyssa    Fischer
# 2746   2747  5FbAa0Be5DBfcC8      Jaime         Yu
# 2923   2924  3C1d193A1cbafC9     Brenda   Odonnell
# 3017   3018  9c2EECf9FBfBfd2       Alan    Vasquez
# 3588   3589  4A48c1A6738E6DC        Joy     Kramer
# 3778   3779  89d2db7DA24A3e8        Pam       Wolf
# 3870   3871  e4bfFBecC356aB3     Autumn    Andrews
# 4660   4661  Ee3F175ECBBAA1c      Diana   Mitchell
# 4994   4995  dCF77D2BB96Cd8d     Debbie      Simon
# ...

# %% [markdown]
# ### 5. List users whose first name starts with "K".

# %%
df[df['First Name'].str.startswith('K')]
# Out:
#       Index      Customer Id First Name  Last Name                   Company  \
# 1         2  10dAcafEBbA5FcA   Kristina    Ferrell  Horn, Shepard and Watson
# 4         5  5820deAdCF23EFe   Kathleen  Mccormick              Carson-Burch
# 17       18  48b3ACBfD6A5cdC        Kim    Griffin              Tyler-Levine
# 18       19  dB52fA7Bec665C1    Kristin   Valencia               Liu-Douglas
# 57       58  fcC8D0ea0ace725       Kurt      Tapia              Adkins-Dixon
# ...     ...              ...        ...        ...                       ...
# 9952   9953  7A84A30c6850Cc5      Kevin      Hobbs               Raymond LLC
# 9955   9956  7eae766C79D1b06     Kristi    Gilmore              Shepherd PLC
# 9969   9970  8dDABC46a53C84B    Kristie    Burgess    Pineda, Webb and Eaton
# 9983   9984  2e9d1d7eEeeE705   Kristina    Mcbride            Mosley-Leblanc
# 9994   9995  D7E40cCBde64d59        Kim      Yoder         Carpenter-Fleming
#
# ...

# %% [markdown]
# ### 6.Who registered after January 1, 2021?

# %%
df['Subscription Date'] = pd.to_datetime(df['Subscription Date'])

afterJan = df[df['Subscription Date'] > '2021-01-01']
afterJan
# Out:
#       Index      Customer Id First Name  Last Name  \
# 2         3  67DAB15Ebe4BE4a     Briana   Andersen
# 4         5  5820deAdCF23EFe   Kathleen  Mccormick
# 5         6  E1CDEaC63fDd5aA     Trevor        Lee
# 7         8  47C5cEE243c9A7b      Glenn    Wiggins
# 9        10  436b9c41cfb1fa3    Brendan     Franco
# ...     ...              ...        ...        ...
# 9993   9994  5B8Ffc59EeBd87D    Bernard       Wolf
# 9994   9995  D7E40cCBde64d59        Kim      Yoder
# 9995   9996  DD0caa06ebf217c     Meghan      Cline
# 9996   9997  C1C62ff90D0AfED   Jeremiah       Pena
# 9997   9998  2EfAa6Fe435A7DA      Peggy        Key
#
#                           Company                City  \
# 2                     Irwin-Oneal         East Jordan
# 4                    Carson-Burch         Andresmouth
# 5                    Maddox Group  Lake Madelineburgh
# 7                    Glenn-Harvey          Ambershire
# 9     Schaefer, Blair and Shaffer          New Rickey
# ...

# %% [markdown]
# ### 7. Show all users whose email ends with ".org".

# %%
df[df['Email'].str.endswith('org')]
# Out:
#       Index      Customer Id First Name   Last Name  \
# 5         6  E1CDEaC63fDd5aA     Trevor         Lee
# 13       14  f8dddbf9CD6FF92       Glen     Hammond
# 17       18  48b3ACBfD6A5cdC        Kim     Griffin
# 25       26  0748BdEFeb4834F  Mackenzie  Williamson
# 31       32  84d3FaE8D176217      Danny       Mayer
# ...     ...              ...        ...         ...
# 9956   9957  dED396249F0cbb2       Jeff      Golden
# 9957   9958  d06B588FCEfCccB       Ivan     Anthony
# 9972   9973  AEfAd4c1ea66Fb4     Dalton     Fischer
# 9978   9979  96ebc7Cc9cfd5dD     Wesley      Hester
# 9992   9993  bdbA1F0053EDA7A   Jennifer      Haynes
#
#                          Company                City                Country  \
# 5                   Maddox Group  Lake Madelineburgh                Senegal
# 13       Schaefer, Chung and Lin          Pamelatown            Netherlands
# 17                  Tyler-Levine       New Gwendolyn  Saint Kitts and Nevis
# ...

# %% [markdown]
# ### 8. Find users whose city and country both start with the same letter.

# %%
df[df['City'].str[0].str.upper() == df['Country'].str[0].str.upper()]
# Out:
#       Index      Customer Id First Name Last Name  \
# 1         2  10dAcafEBbA5FcA   Kristina   Ferrell
# 12       13  c388ECa44FFe37c       Dave     Moran
# 46       47  6ADbBf35FBb6ebc      Tyler   Richard
# 55       56  95CA5DdFfd2279E      Brett   Shelton
# 103     104  6cDfAaf87cd992F      Terri     Hurst
# ...     ...              ...        ...       ...
# 9950   9951  F8A34FbEAffDBDf       Greg     Sharp
# 9953   9954  acfa6d36133e5de     Miguel     Costa
# 9958   9959  fCDd81Aa0cADD38    Caitlin      Tate
# 9966   9967  f21CF91B332Dac8   Margaret     Hines
# 9986   9987  964Cf0C1C6d4a9e    Diamond   Edwards
#
#                               Company              City  \
# 1            Horn, Shepard and Watson        Aaronville
# 12                    Harrell-Donovan   South Elizabeth
# 46                          Cline Inc       Serranoland
# 55                        Beard Group      Salinasmouth
# 103   Shannon, Patterson and Martinez     Lake Omarbury
# ...

# %% [markdown]
# ### 9.How many users are from each country? (Show top 5)

# %%
df['Country'].value_counts().head(5)
# Out:
# Country
# Korea            84
# Congo            81
# Vanuatu          58
# Sierra Leone     56
# Cote d'Ivoire    54
# Name: count, dtype: int64

# %% [markdown]
# ### 10.Count how many users registered in each year.

# %%
df['Subscription year'] = df['Subscription Date'].dt.year
df['Subscription year']
# Out:
# 0       2020
# 1       2020
# 2       2022
# 3       2020
# 4       2021
#         ...
# 9995    2022
# 9996    2022
# 9997    2022
# 9998    2020
# 9999    2020
# Name: Subscription year, Length: 10000, dtype: int32

# %%
df['Subscription year'].value_counts().sort_index()
# Out:
# Subscription year
# 2020    4212
# 2021    4125
# 2022    1663
# Name: count, dtype: int64

# %% [markdown]
# ### 11.Which company (organization) has the most users?

# %%
df['Company'].value_counts().head(1)
# Out:
# Company
# Perry LLC    4
# Name: count, dtype: int64

# %% [markdown]
# ### 12. How many users have phone numbers with extensions (i.e., contain 'x')?

# %%
df['Phone 1'].str.contains('x', na = False).sum()
# Out:
# 5982

# %%
df['Phone 2'].str.contains('x', na = False).sum()
# Out:
# 5933

# %% [markdown]
# ### 13. What is the earliest and latest registration date?

# %%
df['Subscription Date'].min()
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
df['Subscription Date'].max()
# Out:
# Timestamp('2022-05-29 00:00:00')

# %% [markdown]
# ### 14. Which month had the most user registrations?

# %%
df['Reg_month'] = df['Subscription Date'].dt.to_period('M')

df['Reg_month'].value_counts().sort_index().idxmax()
# Out:
# Period('2021-03', 'M')

# %% [markdown]
# ### 15. Create a column that extracts just the year from the registration date.

# %%
df['Year'] = df['Subscription Date'].dt.year
df['Year']
# Out:
# 0       2020
# 1       2020
# 2       2022
# 3       2020
# 4       2021
#         ...
# 9995    2022
# 9996    2022
# 9997    2022
# 9998    2020
# 9999    2020
# Name: Year, Length: 10000, dtype: int32

# %% [markdown]
# ### 16. How many users registered in April 2021?

# %%
df['MY'] = ((df['Subscription Date'].dt.year == 2021) & (df['Subscription Date'].dt.month == 4))
df['MY'].sum()
# Out:
# 306

# %%
april_2021_users = df[
    (df['Subscription Date'].dt.year == 2021) & 
    (df['Subscription Date'].dt.month == 4)]

len(april_2021_users)
# Out:
# 306

# %% [markdown]
# ### 17. Extract the email domain (e.g., gmail.com, yahoo.com).

# %%
df['Email Domain'] = df['Email'].str.extract(r'@([\w\.-]+)')

df['Email Domain']
# Out:
# 0       espinoza-francis.net
# 1           hall-donovan.com
# 2         blevins-sexton.com
# 3                anthony.com
# 4         rangel-shields.com
#                 ...
# 9995              bates.info
# 9996                wade.com
# 9997      barnett-dorsey.com
# 9998     villegas-wilcox.com
# 9999            martinez.com
# Name: Email Domain, Length: 10000, dtype: object

# %% [markdown]
# ### 18. How many unique email domains are there?

# %%
df['Email Domain'] .nunique()
# Out:
# 6270

# %% [markdown]
# ### 19. Which email domain is used most frequently?

# %%
df['Email Domain'].value_counts().head(1)
# Out:
# Email Domain
# hart.com    14
# Name: count, dtype: int64

# %% [markdown]
# ### 20. Find users whose website uses HTTPS.

# %%
df[df['Website'].str.startswith('https')]
# Out:
#       Index      Customer Id First Name  Last Name  \
# 1         2  10dAcafEBbA5FcA   Kristina    Ferrell
# 2         3  67DAB15Ebe4BE4a     Briana   Andersen
# 3         4  6d350C5E5eDB4EE      Patty      Ponce
# 4         5  5820deAdCF23EFe   Kathleen  Mccormick
# 5         6  E1CDEaC63fDd5aA     Trevor        Lee
# ...     ...              ...        ...        ...
# 9987   9988  A34EAc2b68FfdB9     Brandi     Murphy
# 9988   9989  e7Bc7fFed7CbB55  Gabriella   Friedman
# 9994   9995  D7E40cCBde64d59        Kim      Yoder
# 9996   9997  C1C62ff90D0AfED   Jeremiah       Pena
# 9998   9999  5dB06C3Fab5CCCb       Evan   Humphrey
#
#                          Company                City  \
# 1       Horn, Shepard and Watson          Aaronville
# 2                    Irwin-Oneal         East Jordan
# 3               Richardson Group    East Kristintown
# 4                   Carson-Burch         Andresmouth
# 5                   Maddox Group  Lake Madelineburgh
# ...

# %% [markdown]
# ### 21. Standardize all phone numbers by removing non-numeric characters.

# %%
df['Phone 1 clean'] = df['Phone 1'].str.replace(r'\D','', regex = True)
df['Phone 1 clean']
# Out:
# 0              0437975229
# 1              9320621802
# 2              8352752061
# 3              3023983833
# 4       00118415396831497
#               ...
# 9995     0012701364738419
# 9996      153149476454844
# 9997      520109248226052
# 9998        0014652429979
# 9999     1889682949065400
# Name: Phone 1 clean, Length: 10000, dtype: object

# %%
df['Phone 2 clean'] = df['Phone 2'].str.replace(r'\D','', regex = True)

df['Phone 2 clean']
# Out:
# 0              9151121727
# 1          20917271243651
# 2              5671351918
# 3           1961897767770
# 4           5520512979342
#               ...
# 9995     0013496921755055
# 9996    00129532455025411
# 9997     1602934590195106
# 9998     0016399552116751
# 9999      423632253998740
# Name: Phone 2 clean, Length: 10000, dtype: object

# %% [markdown]
# ### 22. Extract the extension number from phone numbers into a new column.

# %%
df['phone_extention'] = df['Phone 1'].str.extract(r'x(\d+)',expand = False)
df['phone_extention']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4        1497
#         ...
# 9995      419
# 9996     4844
# 9997    26052
# 9998      NaN
# 9999    65400
# Name: phone_extention, Length: 10000, dtype: object

# %%
df['Phone2_extention'] = df['Phone 2'].str.extract(r'x(\d+)',expand = False)
df['Phone2_extention']
# Out:
# 0         NaN
# 1        3651
# 2         NaN
# 3         770
# 4         342
#         ...
# 9995      055
# 9996     5411
# 9997    95106
# 9998      751
# 9999    98740
# Name: Phone2_extention, Length: 10000, dtype: object

# %% [markdown]
# ### 23. How many email addresses start with a vowel?

# %%
vowels = ('a','e','i','o','u')

df[df['Email'].str.lower().str.startswith(vowels)].count().head(1)
# Out:
# Index    1323
# dtype: int64

# %% [markdown]
# ### 24. Find all rows where the phone or secondary phone number is missing or invalid.

# %%
mask = (df['Phone 1'].isnull() )| (df['Phone 1'].str.strip() == ' ' ) | (df['Phone 2'].isnull()) | (df['Phone 2'].str.strip() == ' ')

df[mask]
# Out:
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website, Subscription year, Reg_month, Year, MY, Email Domain, Phone 1 clean, Phone 2 clean, phone_extention, Phone2_extention]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### 25.Sort all users by registration date and find the number of days between signups.

# %%
df.sort_values('Subscription Date').reset_index(drop = True)
# Out:
#       Index      Customer Id First Name  Last Name  \
# 0      2983  a1A4334f7eA2712     Victor     Dennis
# 1      3979  0b8CfA0897d2C01    Maurice    Harrell
# 2        21  28D7BcC82d076F2      Barry    Meadows
# 3      8433  aC3d6e0FE026091       Omar     Snyder
# 4      4997  4d41c0F3D0f7Ea0      Paige     Greene
# ...     ...              ...        ...        ...
# 9995   7234  6f6C9a2fc5b45dA      Billy     Stuart
# 9996   7107  0CcF9BdE3A77D5b       Fred       Bush
# 9997   6674  3F389fdde74aaAB       Alex       Pace
# 9998   5742  A5dbB802e1a7fb5     Shelby      Gross
# 9999   7930  936160E73C3a134  Mackenzie  Singleton
#
#                           Company                City      Country  \
# 0     Medina, Bradford and Medina  Lake Daltonborough      Somalia
# 1                     Mathews LLC         West Janice     Kiribati
# 2        Weiss, King and Morrison            Wallston        Congo
# 3                     Shea-Branch           Ninaburgh     Slovenia
# ...

# %% [markdown]
# ### 26. Create a new column to check if the user ID starts with a letter or a digit.

# %%
df['User_Id_Type'] = df['Customer Id'].str[0].apply(lambda x: 'Letter' if x.isalpha() else 'Digit')

df['User_Id_Type']
# Out:
# 0       Letter
# 1        Digit
# 2        Digit
# 3        Digit
# 4        Digit
#          ...
# 9995    Letter
# 9996    Letter
# 9997     Digit
# 9998     Digit
# 9999     Digit
# Name: User_Id_Type, Length: 10000, dtype: object

# %% [markdown]
# ### 27. What is the average length of user IDs?

# %%
df['Customer Id'].str.len().mean()
# Out:
# 15.0

# %% [markdown]
# ### 28. Are there duplicate user IDs?

# %%
df['Customer Id'].duplicated().any()
# Out:
# False
